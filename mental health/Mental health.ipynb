# %%
#### MENTAL HEALTH DATA SET ####
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('survey.csv')

# %%
df.head(10)
# Out:
#    Age  Gender         Country state self_employed family_history treatment  \
# 0   37  Female   United States    IL            No             No       Yes
# 1   44    Male   United States    IN            No             No        No
# 2   32    Male          Canada                  No             No        No
# 3   31    Male  United Kingdom                  No            Yes       Yes
# 4   31    Male   United States    TX            No             No        No
# 5   33    Male   United States    TN            No            Yes        No
# 6   35  Female   United States    MI            No            Yes       Yes
# 7   39    Male          Canada                  No             No        No
# 8   42  Female   United States    IL            No            Yes       Yes
# 9   23    Male          Canada                  No             No        No
#
#   work_interfere remote_work tech_company  ... wellness_program seek_help  \
# 0          Often          No          Yes  ...               No       Yes
# 1         Rarely          No           No  ...              NaN       NaN
# 2         Rarely          No          Yes  ...               No        No
# 3          Often          No          Yes  ...               No        No
# 4          Never         Yes          Yes  ...              NaN       NaN
# 5      Sometimes          No          Yes  ...               No       NaN
# 6      Sometimes         Yes          Yes  ...               No        No
# 7          Never         Yes          Yes  ...               No        No
# 8      Sometimes          No          Yes  ...               No        No
# 9          Never          No          Yes  ...              NaN       NaN
#
#   mental_health_consequence phys_health_consequence coworkers supervisor  \
# 0                        No                      No       Yes        Yes
# 1                       NaN                      No        No         No
# 2                        No                      No       Yes        Yes
# 3                       Yes                     Yes       Yes         No
# 4                        No                      No       Yes        Yes
# 5                        No                      No       Yes        Yes
# 6                       NaN                     NaN       Yes         No
# 7                        No                      No        No         No
# 8                       NaN                      No       Yes        Yes
# 9                        No                      No       Yes        Yes
#
#   mental_health_interview phys_health_interview mental_vs_physical  \
# 0                      No                   NaN                Yes
# 1                      No                    No                NaN
# 2                     Yes                   Yes                 No
# 3                     NaN                   NaN                 No
# 4                     Yes                   Yes                NaN
# 5                      No                   NaN                NaN
# 6                      No                    No                NaN
# 7                      No                    No                 No
# 8                      No                   NaN                 No
# 9                     NaN                   NaN                Yes
#
#   obs_consequence
# 0              No
# 1              No
# 2              No
# 3             Yes
# 4              No
# 5              No
# 6              No
# 7              No
# 8              No
# 9              No
#
# [10 rows x 22 columns]

# %%
df.shape
# Out:
# (1259, 27)

# %%
## checking information about dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1259 entries, 0 to 1258
# Data columns (total 27 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Timestamp                  1259 non-null   object
#  1   Age                        1259 non-null   int64
#  2   Gender                     1259 non-null   object
#  3   Country                    1259 non-null   object
#  4   state                      744 non-null    object
#  5   self_employed              1241 non-null   object
#  6   family_history             1259 non-null   object
#  7   treatment                  1259 non-null   object
#  8   work_interfere             995 non-null    object
#  9   no_employees               1259 non-null   object
#  10  remote_work                1259 non-null   object
#  11  tech_company               1259 non-null   object
#  12  benefits                   1259 non-null   object
#  13  care_options               1259 non-null   object
#  14  wellness_program           1259 non-null   object
#  15  seek_help                  1259 non-null   object
#  16  anonymity                  1259 non-null   object
#  17  leave                      1259 non-null   object
#  18  mental_health_consequence  1259 non-null   object
#  19  phys_health_consequence    1259 non-null   object
#  20  coworkers                  1259 non-null   object
#  21  supervisor                 1259 non-null   object
#  22  mental_health_interview    1259 non-null   object
#  23  phys_health_interview      1259 non-null   object
#  24  mental_vs_physical         1259 non-null   object
#  25  obs_consequence            1259 non-null   object
#  26  comments                   164 non-null    object
# dtypes: int64(1), object(26)
# memory usage: 265.7+ KB

# %%
### we will check for null values
df.isnull().sum()
# Out:
# Timestamp                       0
# Age                             0
# Gender                          0
# Country                         0
# state                         515
# self_employed                  18
# family_history                  0
# treatment                       0
# work_interfere                264
# no_employees                    0
# remote_work                     0
# tech_company                    0
# benefits                        0
# care_options                    0
# wellness_program                0
# seek_help                       0
# anonymity                       0
# leave                           0
# mental_health_consequence       0
# phys_health_consequence         0
# coworkers                       0
# supervisor                      0
# mental_health_interview         0
# phys_health_interview           0
# mental_vs_physical              0
# obs_consequence                 0
# comments                     1095
# dtype: int64

# %%
## droping duplicates if any.
df=df.drop_duplicates()

# %%
## here we arfe droping columns which we think is not helpful enough.
df = df.drop(columns="Timestamp")
df = df.drop(columns = "no_employees" )
df = df.drop(columns = "leave")
df = df.drop(columns = "anonymity")
df = df.drop(columns = "comments")

# %%
df.head(10)
# Out:
#    Age  Gender         Country state self_employed family_history treatment  \
# 0   37  Female   United States    IL           NaN             No       Yes
# 1   44       M   United States    IN           NaN             No        No
# 2   32    Male          Canada   NaN           NaN             No        No
# 3   31    Male  United Kingdom   NaN           NaN            Yes       Yes
# 4   31    Male   United States    TX           NaN             No        No
# 5   33    Male   United States    TN           NaN            Yes        No
# 6   35  Female   United States    MI           NaN            Yes       Yes
# 7   39       M          Canada   NaN           NaN             No        No
# 8   42  Female   United States    IL           NaN            Yes       Yes
# 9   23    Male          Canada   NaN           NaN             No        No
#
#   work_interfere remote_work tech_company  ... wellness_program   seek_help  \
# 0          Often          No          Yes  ...               No         Yes
# 1         Rarely          No           No  ...       Don't know  Don't know
# 2         Rarely          No          Yes  ...               No          No
# 3          Often          No          Yes  ...               No          No
# 4          Never         Yes          Yes  ...       Don't know  Don't know
# 5      Sometimes          No          Yes  ...               No  Don't know
# 6      Sometimes         Yes          Yes  ...               No          No
# 7          Never         Yes          Yes  ...               No          No
# 8      Sometimes          No          Yes  ...               No          No
# 9          Never          No          Yes  ...       Don't know  Don't know
#
#   mental_health_consequence phys_health_consequence     coworkers supervisor  \
# 0                        No                      No  Some of them        Yes
# 1                     Maybe                      No            No         No
# 2                        No                      No           Yes        Yes
# 3                       Yes                     Yes  Some of them         No
# 4                        No                      No  Some of them        Yes
# 5                        No                      No           Yes        Yes
# 6                     Maybe                   Maybe  Some of them         No
# 7                        No                      No            No         No
# 8                     Maybe                      No           Yes        Yes
# 9                        No                      No           Yes        Yes
#
#   mental_health_interview phys_health_interview mental_vs_physical  \
# 0                      No                 Maybe                Yes
# 1                      No                    No         Don't know
# 2                     Yes                   Yes                 No
# 3                   Maybe                 Maybe                 No
# 4                     Yes                   Yes         Don't know
# 5                      No                 Maybe         Don't know
# 6                      No                    No         Don't know
# 7                      No                    No                 No
# 8                      No                 Maybe                 No
# 9                   Maybe                 Maybe                Yes
#
#   obs_consequence
# 0              No
# 1              No
# 2              No
# 3             Yes
# 4              No
# 5              No
# 6              No
# 7              No
# 8              No
# 9              No
#
# [10 rows x 22 columns]

# %%
## here we are replacing and making every values equal M for male and F for Female

df["Gender"] = df["Gender"].str.replace("Female" , "F")
df["Gender"] = df["Gender"].str.replace("female" , "F")
df["Gender"] = df["Gender"].str.replace("f" , "F")

# %%
df["Gender"] = df["Gender"].str.replace("m" , "M")
df["Gender"] = df["Gender"].str.replace("male" , "M")
df["Gender"] = df["Gender"].str.replace("Male" , "M")

# %%
###replaced genders one by one
df["Gender"] = df["Gender"].str.replace("M-ish" , "M")
df["Gender"] = df["Gender"].str.replace("Cis F" , "Trans-F")
df["Gender"] = df["Gender"].str.replace("soMething kinda M?" , "M")
df["Gender"] = df["Gender"].str.replace("Cis M" , "Trans-M")
df["Gender"] = df["Gender"].str.replace("WoMan" , "F")
df["Gender"] = df["Gender"].str.replace("Mal" , "M")
df["Gender"] = df["Gender"].str.replace("M (CIS)" , "Trans-M")
df["Gender"] = df["Gender"].str.replace("FeMake" , "F")
df["Gender"] = df["Gender"].str.replace("Make" , "M")
df["Gender"] = df["Gender"].str.replace("Enby" , "non-binary")
df["Gender"] = df["Gender"].str.replace("Fluid" , "non-binary")
df["Gender"] = df["Gender"].str.replace("Androgyne" , "non-binary")
df["Gender"] = df["Gender"].str.replace("Agender" , "non-binary")
df["Gender"] = df["Gender"].str.replace("cis-F/FeMMe" , "Trans-F")
df["Gender"] = df["Gender"].str.replace("Guy (-ish) ^_^" , "M")
df["Gender"] = df["Gender"].str.replace("M leaning androgynous" , "non-binary")
df["Gender"] = df["Gender"].str.replace("Man" , "M")
df["Gender"] = df["Gender"].str.replace("Trans woMan" , "Trans-F")
df["Gender"] = df["Gender"].str.replace("Msle" , "M")
df["Gender"] = df["Gender"].str.replace("Neuter" , "non-binary")
df["Gender"] = df["Gender"].str.replace("F (trans)" , "Trans-F")
df["Gender"] = df["Gender"].str.replace("F (cis)" , "Trans-F")
df["Gender"] = df["Gender"].str.replace("Mail" , "M")
df["Gender"] = df["Gender"].str.replace("A little about you" , "Child")
df["Gender"] = df["Gender"].str.replace("Malr" , "M")
df["Gender"] = df["Gender"].str.replace("FeMail" , "F")
df["Gender"] = df["Gender"].str.replace("ostensibly M, unsure what that really Means" , "M")
df["Gender"] = df["Gender"].str.replace("queer/she/they" , "non-binary")
df["Gender"] = df["Gender"].str.replace("woM" ,"F")
df["Gender"] = df["Gender"].str.replace("Nah" , "non-binary")
df["Gender"] = df["Gender"].str.replace("All" , "non-binary")
df["Gender"] = df["Gender"].str.replace("Genderqueer" , "non-binary")
df["Gender"] = df["Gender"].str.replace("Trans woM" , "Trans-F")
df["Gender"] = df["Gender"].str.replace("queer" , "non-binary")
df["Gender"] = df["Gender"].str.replace("cis M" , "Trans-M")
df["Gender"] = df["Gender"].str.replace("FeM" , "F")
df["Gender"] = df["Gender"].str.replace("Me" , "M")
df["Gender"] = df["Gender"].str.replace("Maler" , "M")

# %%
### filing NA with empty spaces
df =df.fillna("")

# %%
df.replace("N/a" , "")
# Out:
#       Age Gender         Country state self_employed family_history treatment  \
# 0      37      F   United States    IL                           No       Yes
# 1      44      M   United States    IN                           No        No
# 2      32      M          Canada                                 No        No
# 3      31      M  United Kingdom                                Yes       Yes
# 4      31      M   United States    TX                           No        No
# ...   ...    ...             ...   ...           ...            ...       ...
# 1254   26      M  United Kingdom                  No             No       Yes
# 1255   32      M   United States    IL            No            Yes       Yes
# 1256   34      M   United States    CA            No            Yes       Yes
# 1257   46      F   United States    NC            No             No        No
# 1258   25      M   United States    IL            No            Yes       Yes
#
#      work_interfere remote_work tech_company  ... wellness_program  \
# 0             Often          No          Yes  ...               No
# 1            Rarely          No           No  ...       Don't know
# 2            Rarely          No          Yes  ...               No
# 3             Often          No          Yes  ...               No
# 4             Never         Yes          Yes  ...       Don't know
# ...             ...         ...          ...  ...              ...
# 1254                         No          Yes  ...               No
# 1255          Often         Yes          Yes  ...               No
# 1256      Sometimes          No          Yes  ...               No
# 1257                        Yes          Yes  ...               No
# 1258      Sometimes          No           No  ...               No
#
#        seek_help mental_health_consequence phys_health_consequence coworkers  \
# 0            Yes                        No                      No       Yes
# 1     Don't know                     Maybe                      No        No
# 2             No                        No                      No       Yes
# 3             No                       Yes                     Yes       Yes
# 4     Don't know                        No                      No       Yes
# ...          ...                       ...                     ...       ...
# 1254          No                        No                      No       Yes
# 1255          No                        No                      No       Yes
# 1256          No                       Yes                     Yes        No
# 1257          No                       Yes                      No        No
# 1258          No                     Maybe                      No       Yes
#
#      supervisor mental_health_interview phys_health_interview  \
# 0           Yes                      No                 Maybe
# 1            No                      No                    No
# 2           Yes                     Yes                   Yes
# 3            No                   Maybe                 Maybe
# 4           Yes                     Yes                   Yes
# ...         ...                     ...                   ...
# 1254        Yes                      No                    No
# 1255        Yes                      No                    No
# 1256         No                      No                    No
# 1257         No                      No                    No
# 1258         No                      No                    No
#
#      mental_vs_physical obs_consequence
# 0                   Yes              No
# 1            Don't know              No
# 2                    No              No
# 3                    No             Yes
# 4            Don't know              No
# ...                 ...             ...
# 1254         Don't know              No
# 1255                Yes              No
# 1256                 No              No
# 1257                 No              No
# 1258         Don't know              No
#
# [1259 rows x 22 columns]

# %%
## some of them is effecting mental health so we can assume yes some one is effecting the mental health
df["coworkers"] = df["coworkers"].str.replace("Some of them" , "Yes")
df["supervisor"] = df["supervisor"].str.replace("Some of them" , "Yes")

# %%
### checking
df.head(10)
# Out:
#    Age Gender         Country state self_employed family_history treatment  \
# 0   37      F   United States    IL                           No       Yes
# 1   44      M   United States    IN                           No        No
# 2   32      M          Canada                                 No        No
# 3   31      M  United Kingdom                                Yes       Yes
# 4   31      M   United States    TX                           No        No
# 5   33      M   United States    TN                          Yes        No
# 6   35      F   United States    MI                          Yes       Yes
# 7   39      M          Canada                                 No        No
# 8   42      F   United States    IL                          Yes       Yes
# 9   23      M          Canada                                 No        No
#
#   work_interfere remote_work tech_company  ... wellness_program   seek_help  \
# 0          Often          No          Yes  ...               No         Yes
# 1         Rarely          No           No  ...       Don't know  Don't know
# 2         Rarely          No          Yes  ...               No          No
# 3          Often          No          Yes  ...               No          No
# 4          Never         Yes          Yes  ...       Don't know  Don't know
# 5      Sometimes          No          Yes  ...               No  Don't know
# 6      Sometimes         Yes          Yes  ...               No          No
# 7          Never         Yes          Yes  ...               No          No
# 8      Sometimes          No          Yes  ...               No          No
# 9          Never          No          Yes  ...       Don't know  Don't know
#
#   mental_health_consequence phys_health_consequence coworkers supervisor  \
# 0                        No                      No       Yes        Yes
# 1                     Maybe                      No        No         No
# 2                        No                      No       Yes        Yes
# 3                       Yes                     Yes       Yes         No
# 4                        No                      No       Yes        Yes
# 5                        No                      No       Yes        Yes
# 6                     Maybe                   Maybe       Yes         No
# 7                        No                      No        No         No
# 8                     Maybe                      No       Yes        Yes
# 9                        No                      No       Yes        Yes
#
#   mental_health_interview phys_health_interview mental_vs_physical  \
# 0                      No                 Maybe                Yes
# 1                      No                    No         Don't know
# 2                     Yes                   Yes                 No
# 3                   Maybe                 Maybe                 No
# 4                     Yes                   Yes         Don't know
# 5                      No                 Maybe         Don't know
# 6                      No                    No         Don't know
# 7                      No                    No                 No
# 8                      No                 Maybe                 No
# 9                   Maybe                 Maybe                Yes
#
#   obs_consequence
# 0              No
# 1              No
# 2              No
# 3             Yes
# 4              No
# 5              No
# 6              No
# 7              No
# 8              No
# 9              No
#
# [10 rows x 22 columns]

# %%
### before when we where replacing M with male and F with female we were getting wrong data all f and m were replaced even from male word m(maleale) so now we can replace .
df["Gender"] = df["Gender"].str.replace("M" , "Male")
df["Gender"] = df["Gender"].str.replace("F" , "Female")

# %%
## checking
df.head(10)
# Out:
#    Age  Gender         Country state self_employed family_history treatment  \
# 0   37  Female   United States    IL                           No       Yes
# 1   44    Male   United States    IN                           No        No
# 2   32    Male          Canada                                 No        No
# 3   31    Male  United Kingdom                                Yes       Yes
# 4   31    Male   United States    TX                           No        No
# 5   33    Male   United States    TN                          Yes        No
# 6   35  Female   United States    MI                          Yes       Yes
# 7   39    Male          Canada                                 No        No
# 8   42  Female   United States    IL                          Yes       Yes
# 9   23    Male          Canada                                 No        No
#
#   work_interfere remote_work tech_company  ... wellness_program   seek_help  \
# 0          Often          No          Yes  ...               No         Yes
# 1         Rarely          No           No  ...       Don't know  Don't know
# 2         Rarely          No          Yes  ...               No          No
# 3          Often          No          Yes  ...               No          No
# 4          Never         Yes          Yes  ...       Don't know  Don't know
# 5      Sometimes          No          Yes  ...               No  Don't know
# 6      Sometimes         Yes          Yes  ...               No          No
# 7          Never         Yes          Yes  ...               No          No
# 8      Sometimes          No          Yes  ...               No          No
# 9          Never          No          Yes  ...       Don't know  Don't know
#
#   mental_health_consequence phys_health_consequence coworkers supervisor  \
# 0                        No                      No       Yes        Yes
# 1                     Maybe                      No        No         No
# 2                        No                      No       Yes        Yes
# 3                       Yes                     Yes       Yes         No
# 4                        No                      No       Yes        Yes
# 5                        No                      No       Yes        Yes
# 6                     Maybe                   Maybe       Yes         No
# 7                        No                      No        No         No
# 8                     Maybe                      No       Yes        Yes
# 9                        No                      No       Yes        Yes
#
#   mental_health_interview phys_health_interview mental_vs_physical  \
# 0                      No                 Maybe                Yes
# 1                      No                    No         Don't know
# 2                     Yes                   Yes                 No
# 3                   Maybe                 Maybe                 No
# 4                     Yes                   Yes         Don't know
# 5                      No                 Maybe         Don't know
# 6                      No                    No         Don't know
# 7                      No                    No                 No
# 8                      No                 Maybe                 No
# 9                   Maybe                 Maybe                Yes
#
#   obs_consequence
# 0              No
# 1              No
# 2              No
# 3             Yes
# 4              No
# 5              No
# 6              No
# 7              No
# 8              No
# 9              No
#
# [10 rows x 22 columns]

# %%
#In many cases, "maybe" entries can be treated similarly to missing data, especially if they indicate uncertainty or lack of a definitive response. You can replace "maybe" with NaN values using Pandas:
df.replace('Maybe', np.nan, inplace=True)

# %%
#similary to Don't Know
df.replace("Don't know", np.nan, inplace=True)

# %%
### as we see dataset trend we observed NA can be replaced from No
df["self_employed"]=df["self_employed"].replace("" , "No")

# %%
df.reset_index(drop = True)
# Out:
#       Age  Gender         Country state self_employed family_history  \
# 0      37  Female   United States    IL            No             No
# 1      44    Male   United States    IN            No             No
# 2      32    Male          Canada                  No             No
# 3      31    Male  United Kingdom                  No            Yes
# 4      31    Male   United States    TX            No             No
# ...   ...     ...             ...   ...           ...            ...
# 1254   26    Male  United Kingdom                  No             No
# 1255   32    Male   United States    IL            No            Yes
# 1256   34    Male   United States    CA            No            Yes
# 1257   46  Female   United States    NC            No             No
# 1258   25    Male   United States    IL            No            Yes
#
#      treatment work_interfere remote_work tech_company  ... wellness_program  \
# 0          Yes          Often          No          Yes  ...               No
# 1           No         Rarely          No           No  ...              NaN
# 2           No         Rarely          No          Yes  ...               No
# 3          Yes          Often          No          Yes  ...               No
# 4           No          Never         Yes          Yes  ...              NaN
# ...        ...            ...         ...          ...  ...              ...
# 1254       Yes                         No          Yes  ...               No
# 1255       Yes          Often         Yes          Yes  ...               No
# 1256       Yes      Sometimes          No          Yes  ...               No
# 1257        No                        Yes          Yes  ...               No
# 1258       Yes      Sometimes          No           No  ...               No
#
#      seek_help mental_health_consequence phys_health_consequence coworkers  \
# 0          Yes                        No                      No       Yes
# 1          NaN                       NaN                      No        No
# 2           No                        No                      No       Yes
# 3           No                       Yes                     Yes       Yes
# 4          NaN                        No                      No       Yes
# ...        ...                       ...                     ...       ...
# 1254        No                        No                      No       Yes
# 1255        No                        No                      No       Yes
# 1256        No                       Yes                     Yes        No
# 1257        No                       Yes                      No        No
# 1258        No                       NaN                      No       Yes
#
#      supervisor mental_health_interview phys_health_interview  \
# 0           Yes                      No                   NaN
# 1            No                      No                    No
# 2           Yes                     Yes                   Yes
# 3            No                     NaN                   NaN
# 4           Yes                     Yes                   Yes
# ...         ...                     ...                   ...
# 1254        Yes                      No                    No
# 1255        Yes                      No                    No
# 1256         No                      No                    No
# 1257         No                      No                    No
# 1258         No                      No                    No
#
#      mental_vs_physical obs_consequence
# 0                   Yes              No
# 1                   NaN              No
# 2                    No              No
# 3                    No             Yes
# 4                   NaN              No
# ...                 ...             ...
# 1254                NaN              No
# 1255                Yes              No
# 1256                 No              No
# 1257                 No              No
# 1258                NaN              No
#
# [1259 rows x 22 columns]

# %%
df.head(10)
# Out:
#    Age  Gender         Country state self_employed family_history treatment  \
# 0   37  Female   United States    IL            No             No       Yes
# 1   44    Male   United States    IN            No             No        No
# 2   32    Male          Canada                  No             No        No
# 3   31    Male  United Kingdom                  No            Yes       Yes
# 4   31    Male   United States    TX            No             No        No
# 5   33    Male   United States    TN            No            Yes        No
# 6   35  Female   United States    MI            No            Yes       Yes
# 7   39    Male          Canada                  No             No        No
# 8   42  Female   United States    IL            No            Yes       Yes
# 9   23    Male          Canada                  No             No        No
#
#   work_interfere remote_work tech_company  ... wellness_program seek_help  \
# 0          Often          No          Yes  ...               No       Yes
# 1         Rarely          No           No  ...              NaN       NaN
# 2         Rarely          No          Yes  ...               No        No
# 3          Often          No          Yes  ...               No        No
# 4          Never         Yes          Yes  ...              NaN       NaN
# 5      Sometimes          No          Yes  ...               No       NaN
# 6      Sometimes         Yes          Yes  ...               No        No
# 7          Never         Yes          Yes  ...               No        No
# 8      Sometimes          No          Yes  ...               No        No
# 9          Never          No          Yes  ...              NaN       NaN
#
#   mental_health_consequence phys_health_consequence coworkers supervisor  \
# 0                        No                      No       Yes        Yes
# 1                       NaN                      No        No         No
# 2                        No                      No       Yes        Yes
# 3                       Yes                     Yes       Yes         No
# 4                        No                      No       Yes        Yes
# 5                        No                      No       Yes        Yes
# 6                       NaN                     NaN       Yes         No
# 7                        No                      No        No         No
# 8                       NaN                      No       Yes        Yes
# 9                        No                      No       Yes        Yes
#
#   mental_health_interview phys_health_interview mental_vs_physical  \
# 0                      No                   NaN                Yes
# 1                      No                    No                NaN
# 2                     Yes                   Yes                 No
# 3                     NaN                   NaN                 No
# 4                     Yes                   Yes                NaN
# 5                      No                   NaN                NaN
# 6                      No                    No                NaN
# 7                      No                    No                 No
# 8                      No                   NaN                 No
# 9                     NaN                   NaN                Yes
#
#   obs_consequence
# 0              No
# 1              No
# 2              No
# 3             Yes
# 4              No
# 5              No
# 6              No
# 7              No
# 8              No
# 9              No
#
# [10 rows x 22 columns]

# %%
### here we have some columns in negative and also more than 100 which can be outlliers so we can remove them
for x in df.index:
  if df.loc[x , "Age"] > 150 or df.loc[x , "Age"] < 1:
    df.drop(x , inplace = True)
df
# Out:
#       Age  Gender         Country state self_employed family_history  \
# 0      37  Female   United States    IL            No             No
# 1      44    Male   United States    IN            No             No
# 2      32    Male          Canada                  No             No
# 3      31    Male  United Kingdom                  No            Yes
# 4      31    Male   United States    TX            No             No
# ...   ...     ...             ...   ...           ...            ...
# 1254   26    Male  United Kingdom                  No             No
# 1255   32    Male   United States    IL            No            Yes
# 1256   34    Male   United States    CA            No            Yes
# 1257   46  Female   United States    NC            No             No
# 1258   25    Male   United States    IL            No            Yes
#
#      treatment work_interfere remote_work tech_company  ... wellness_program  \
# 0          Yes          Often          No          Yes  ...               No
# 1           No         Rarely          No           No  ...              NaN
# 2           No         Rarely          No          Yes  ...               No
# 3          Yes          Often          No          Yes  ...               No
# 4           No          Never         Yes          Yes  ...              NaN
# ...        ...            ...         ...          ...  ...              ...
# 1254       Yes                         No          Yes  ...               No
# 1255       Yes          Often         Yes          Yes  ...               No
# 1256       Yes      Sometimes          No          Yes  ...               No
# 1257        No                        Yes          Yes  ...               No
# 1258       Yes      Sometimes          No           No  ...               No
#
#      seek_help mental_health_consequence phys_health_consequence coworkers  \
# 0          Yes                        No                      No       Yes
# 1          NaN                       NaN                      No        No
# 2           No                        No                      No       Yes
# 3           No                       Yes                     Yes       Yes
# 4          NaN                        No                      No       Yes
# ...        ...                       ...                     ...       ...
# 1254        No                        No                      No       Yes
# 1255        No                        No                      No       Yes
# 1256        No                       Yes                     Yes        No
# 1257        No                       Yes                      No        No
# 1258        No                       NaN                      No       Yes
#
#      supervisor mental_health_interview phys_health_interview  \
# 0           Yes                      No                   NaN
# 1            No                      No                    No
# 2           Yes                     Yes                   Yes
# 3            No                     NaN                   NaN
# 4           Yes                     Yes                   Yes
# ...         ...                     ...                   ...
# 1254        Yes                      No                    No
# 1255        Yes                      No                    No
# 1256         No                      No                    No
# 1257         No                      No                    No
# 1258         No                      No                    No
#
#      mental_vs_physical obs_consequence
# 0                   Yes              No
# 1                   NaN              No
# 2                    No              No
# 3                    No             Yes
# 4                   NaN              No
# ...                 ...             ...
# 1254                NaN              No
# 1255                Yes              No
# 1256                 No              No
# 1257                 No              No
# 1258                NaN              No
#
# [1254 rows x 22 columns]

# %%
df.reset_index(drop = True)
# Out:
#       Age  Gender         Country state self_employed family_history  \
# 0      37  Female   United States    IL            No             No
# 1      44    Male   United States    IN            No             No
# 2      32    Male          Canada                  No             No
# 3      31    Male  United Kingdom                  No            Yes
# 4      31    Male   United States    TX            No             No
# ...   ...     ...             ...   ...           ...            ...
# 1249   26    Male  United Kingdom                  No             No
# 1250   32    Male   United States    IL            No            Yes
# 1251   34    Male   United States    CA            No            Yes
# 1252   46  Female   United States    NC            No             No
# 1253   25    Male   United States    IL            No            Yes
#
#      treatment work_interfere remote_work tech_company  ... wellness_program  \
# 0          Yes          Often          No          Yes  ...               No
# 1           No         Rarely          No           No  ...              NaN
# 2           No         Rarely          No          Yes  ...               No
# 3          Yes          Often          No          Yes  ...               No
# 4           No          Never         Yes          Yes  ...              NaN
# ...        ...            ...         ...          ...  ...              ...
# 1249       Yes                         No          Yes  ...               No
# 1250       Yes          Often         Yes          Yes  ...               No
# 1251       Yes      Sometimes          No          Yes  ...               No
# 1252        No                        Yes          Yes  ...               No
# 1253       Yes      Sometimes          No           No  ...               No
#
#      seek_help mental_health_consequence phys_health_consequence coworkers  \
# 0          Yes                        No                      No       Yes
# 1          NaN                       NaN                      No        No
# 2           No                        No                      No       Yes
# 3           No                       Yes                     Yes       Yes
# 4          NaN                        No                      No       Yes
# ...        ...                       ...                     ...       ...
# 1249        No                        No                      No       Yes
# 1250        No                        No                      No       Yes
# 1251        No                       Yes                     Yes        No
# 1252        No                       Yes                      No        No
# 1253        No                       NaN                      No       Yes
#
#      supervisor mental_health_interview phys_health_interview  \
# 0           Yes                      No                   NaN
# 1            No                      No                    No
# 2           Yes                     Yes                   Yes
# 3            No                     NaN                   NaN
# 4           Yes                     Yes                   Yes
# ...         ...                     ...                   ...
# 1249        Yes                      No                    No
# 1250        Yes                      No                    No
# 1251         No                      No                    No
# 1252         No                      No                    No
# 1253         No                      No                    No
#
#      mental_vs_physical obs_consequence
# 0                   Yes              No
# 1                   NaN              No
# 2                    No              No
# 3                    No             Yes
# 4                   NaN              No
# ...                 ...             ...
# 1249                NaN              No
# 1250                Yes              No
# 1251                 No              No
# 1252                 No              No
# 1253                NaN              No
#
# [1254 rows x 22 columns]

# %%
df.to_csv('survey_cleaned.csv')
